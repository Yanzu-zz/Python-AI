# %% [raw]
# scikit-learn 中的逻辑回归

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(666)
X = np.random.normal(0, 1, size=(200, 2))
y = np.array(X[:, 0]**2 + X[:, 1] < 1.5, dtype='int')

# 为样本添加一些噪音
for _ in range(20):
    y[np.random.randint(200)] = 1

# %%
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %% [raw]
# 开始使用 sklearn-learn 中的逻辑回归

# %%
# 注意这里是 sklearn 的 LogisticRegression，不是自己写的了
from sklearn.linear_model import LogisticRegression

# 先试试线性模拟
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(log_reg.score(X_train, y_train))
print(log_reg.score(X_test, y_test))
# Out:
# 0.7933333333333333
# 0.86

# %%
def plot_decision_boundary(model, axis):
    
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1),
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]

    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)

    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A','#FFF59D','#90CAF9'])
    
    plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
plot_decision_boundary(log_reg, axis=[-4, 4, -4, 4])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()
# Out:
# C:\Users\IAdmin\AppData\Local\Temp\ipykernel_2136\2833637709.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

def PolynomialLogisticRegression(degree):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        # 注意，下面这个逻辑回归是我们自己写的
        # 可以写进管道是应为我们遵守了 sklearn 标准
        ('log_reg', LogisticRegression())
    ])

# %%
poly_log_reg = PolynomialLogisticRegression(degree=2)
poly_log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('std_scaler', StandardScaler()),
#                 ('log_reg', LogisticRegression())])

# %%
print(poly_log_reg.score(X_train, y_train))
print(poly_log_reg.score(X_test, y_test))
# Out:
# 0.9066666666666666
# 0.94

# %%
plot_decision_boundary(poly_log_reg, axis=[-4, 4, -4, 4])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()
# Out:
# C:\Users\IAdmin\AppData\Local\Temp\ipykernel_2136\2833637709.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
poly_log_reg2 = PolynomialLogisticRegression(degree=20)
poly_log_reg2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=20)),
#                 ('std_scaler', StandardScaler()),
#                 ('log_reg', LogisticRegression())])

# %%
print(poly_log_reg2.score(X_train, y_train))
print(poly_log_reg2.score(X_test, y_test))
# Out:
# 0.94
# 0.92

# %%
plot_decision_boundary(poly_log_reg2, axis=[-4, 4, -4, 4])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()
# Out:
# C:\Users\IAdmin\AppData\Local\Temp\ipykernel_2136\2833637709.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %% [raw]
# 进行模型正则化

# %%
# sklearn 都帮我们写好了，我们传参就行
def PolynomialLogisticRegression(degree, C):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        ('log_reg', LogisticRegression(C=C))
    ])

# %%
poly_log_reg3 = PolynomialLogisticRegression(degree=20, C=0.1)
poly_log_reg3.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=20)),
#                 ('std_scaler', StandardScaler()),
#                 ('log_reg', LogisticRegression(C=0.1))])

# %%
print(poly_log_reg3.score(X_train, y_train))
print(poly_log_reg3.score(X_test, y_test))
# Out:
# 0.84
# 0.92

# %%
plot_decision_boundary(poly_log_reg3, axis=[-4, 4, -4, 4])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()
# Out:
# C:\Users\IAdmin\AppData\Local\Temp\ipykernel_2136\2833637709.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
def PolynomialLogisticRegression(degree, C, penalty='l2'):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        ('log_reg', LogisticRegression(C=C, penalty=penalty))
    ])

# %%
# 这里试试 L1正则项
poly_log_reg4 = PolynomialLogisticRegression(degree=20, C=0.1, penalty='l1')
poly_log_reg4.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 # 这里试试 L1正则项
#       2 poly_log_reg4 = PolynomialLogisticRegression(degree=20, C=0.1, penalty='l1')
# ----> 3 poly_log_reg4.fit(X_train, y_train)
#
# File ~\Software\Dev_Tools\Anaconda\envs\imooc_ai\Lib\site-packages\sklearn\pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~\Software\Dev_Tools\Anaconda\envs\imooc_ai\Lib\site-packages\sklearn\linear_model\_logistic.py:1162, in LogisticRegression.fit(self, X, y, sample_weight)
#    1131 """
#    1132 Fit the model according to the given training data.
#    1133
#    (...)
#    1157 The SAGA solver supports both float64 and float32 bit arrays.
#    1158 """
#    1160 self._validate_params()
# -> 1162 solver = _check_solver(self.solver, self.penalty, self.dual)
#    1164 if self.penalty != "elasticnet" and self.l1_ratio is not None:
#    1165     warnings.warn(
#    1166         "l1_ratio parameter is only used when penalty is "
#    1167         "'elasticnet'. Got "
#    1168         "(penalty={})".format(self.penalty)
#    1169     )
#
# File ~\Software\Dev_Tools\Anaconda\envs\imooc_ai\Lib\site-packages\sklearn\linear_model\_logistic.py:54, in _check_solver(solver, penalty, dual)
#      50 def _check_solver(solver, penalty, dual):
#      51
#      52     # TODO(1.4): Remove "none" option
#      53     if solver not in ["liblinear", "saga"] and penalty not in ("l2", "none", None):
# ---> 54         raise ValueError(
#      55             "Solver %s supports only 'l2' or 'none' penalties, got %s penalty."
#      56             % (solver, penalty)
#      57         )
#      58     if solver != "liblinear" and dual:
#      59         raise ValueError(
#      60             "Solver %s supports only dual=False, got dual=%s" % (solver, dual)
#      61         )
#
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.

# %%
print(poly_log_reg4.score(X_train, y_train))
print(poly_log_reg4.score(X_test, y_test))
# Out:
# 0.84
# 0.92

# %%
plot_decision_boundary(poly_log_reg4, axis=[-4, 4, -4, 4])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()
# Out:
# C:\Users\IAdmin\AppData\Local\Temp\ipykernel_2136\2833637709.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)
