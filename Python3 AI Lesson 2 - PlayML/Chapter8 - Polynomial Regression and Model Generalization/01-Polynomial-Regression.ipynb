# %% [raw]
# 用线性回归来拟合非线性关系的数据（一眼不够好）

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3, 3, size=100)
X = x.reshape(-1, 1)

# %%
# x 的二次函数
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_predict = lin_reg.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color='r')
plt.show()

# %% [raw]
# 来看多项式回归的思路
# 解决方案：添加一个特征

# %%
# 根据原来的 X 与 X^2 推迭在一起
# 也就是手动添加一个特征
X2 = np.hstack([X, X**2])
X2.shape
# Out:
# (100, 2)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X2, y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color='r')
plt.show()

# %%
# 第一个系数是 x 的系数，第二个是 x^2 的系数
lin_reg2.coef_
# Out:
# array([1.02278361, 0.52590226])

# %%
# 截距也和我们手动定义的 +2 接近
lin_reg2.intercept_
# Out:
# 1.9504487051166481
