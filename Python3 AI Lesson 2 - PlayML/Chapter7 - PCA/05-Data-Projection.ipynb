# %% [raw]
# 从高维数据向低维数据的映射

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100, 2))
X[:, 0] = np.random.uniform(0., 100., size=100)
X[:, 1] = 0.75 * X[:, 0] + 3. + np.random.normal(0, 10., size=100)

# %%
import sys
sys.path.insert(0, '../PlayML')
from PCA import PCA

pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.78796145,  0.61572458],
#        [-0.61572203,  0.78796344]])

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
# 降维
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
# 恢复成高维，注意，此时信息有丢失
X_restore = pca.inverse_transform(X_reduction)

# %%
X_restore.shape
# Out:
# (100, 2)

# %%
# visualize the data
plt.scatter(X[:, 0], X[:, 1], color='b', alpha=0.5)
plt.scatter(X_restore[:, 0], X_restore[:, 1], color='r', alpha=0.5)
plt.show()

# %% [raw]
# scikit-learn 中的 PCA

# %%
from sklearn.decomposition import PCA

# sklean 不是用梯度上升法求解的，是用数学的方法
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
pca.components_
# Out:
# array([[0.78796142, 0.61572461]])

# %%
X_reduction = pca.transform(X)
X.shape
# Out:
# (100, 2)

# %%
X_restore = pca.inverse_transform(X_reduction)
X_restore.shape
# Out:
# (100, 2)

# %%
# visualize the data
plt.scatter(X[:, 0], X[:, 1], color='b', alpha=0.5)
plt.scatter(X_restore[:, 0], X_restore[:, 1], color='r', alpha=0.5)
plt.show()
